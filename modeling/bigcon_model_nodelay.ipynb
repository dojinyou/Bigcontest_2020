# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
from pathlib import Path

folder = "bigcon2020/data"
base_path = Path("/content/drive/My Drive/")
project_path = base_path / folder
os.chdir(project_path)
for x in list(project_path.glob("*")):
    if x.is_dir():
        dir_name = str(x.relative_to(project_path))
        os.rename(dir_name, dir_name.split(" ", 1)[0])
print(f"현재 디렉토리 위치: {os.getcwd()}")
# Out:
# 현재 디렉토리 위치: /content/drive/My Drive/bigcon2020/data

# %%
import tensorflow as tf
from tensorflow.keras import layers

print('tensorflow version: {}'.format(tf.__version__))
print('GPU 사용 가능 여부: {}'.format(tf.test.is_gpu_available()))
# Out:
# tensorflow version: 2.3.0
# GPU 사용 가능 여부: True

# %%
batch_size = 9
max_epochs = 50
learning_rate = 1e-5
hidden_sizes = [128, 128]

# %%
def preprocess():
  # 1차_최종_공통 : 시즌, 홈어웨이, 경기간간격, 득점, 실점, 승패
  general = pd.read_csv('1차_최종_공통.csv')
  general = general[general['팀코드']=='NC']
  general = general[['게임키', '경기간간격','결과']]
  general['시즌'] = general['게임키'].apply(lambda x:int(x[:4]))
  general['홈어웨이'] = general['게임키'].apply(lambda x:0 if x[-3:-1]=='NC' else 1)
  general=general.set_index('게임키')
  # 팀타자 : 기준팀, 상대팀 wRC
  hitter = pd.read_csv('1차_최종_팀타자.csv')
  hitter_vs = hitter[hitter['상대팀코드']=='NC']
  hitter = hitter[hitter['팀코드']=='NC']
  hitter = hitter[['게임키', 'wRC','RC','RC27']]
  hitter_vs = hitter_vs[['게임키', 'wRC', 'RC','RC27']]
  hitter=hitter.set_index('게임키')
  hitter_vs=hitter_vs.set_index('게임키')
  hitter_vs=hitter_vs.add_prefix('vs_')
  # 팀투수 : 기준팀, 상대팀 RA/9, whip
  pitcher = pd.read_csv('1차_최종_팀투수.csv')
  pitcher_vs = pitcher[pitcher['상대팀코드']=='NC']
  pitcher = pitcher[pitcher['팀코드']=='NC']
  pitcher = pitcher[['게임키', 'RA/9','whip','F-E','OOPS']]
  pitcher_vs = pitcher_vs[['게임키', 'RA/9','whip','F-E','OOPS']]
  pitcher = pitcher.set_index('게임키')
  pitcher_vs = pitcher_vs.set_index('게임키')
  pitcher_vs = pitcher_vs.add_prefix('vs_')
  df = pd.concat([general, hitter,hitter_vs, pitcher,pitcher_vs], axis=1)
  df= df[['시즌','경기간간격','홈어웨이','wRC','RA/9','RC27','vs_wRC','vs_RC','vs_RC27','RC','whip','F-E','OOPS','vs_RA/9','vs_whip','vs_F-E','vs_OOPS','결과']]
  df['결과'] = df['결과'].apply(lambda x : 0 if x =='W' else 1)
  return df

# %%
df = preprocess()
df.head()
# Out:
#                  시즌  경기간간격  홈어웨이     wRC  ...  vs_whip  vs_F-E  vs_OOPS  결과
# 게임키                                       ...
# 20160401HTNC0  2016    0.0     0   0.000  ...    0.000   0.000    0.000   0
# 20160402HTNC0  2016    1.0     0   7.039  ...    1.750   1.023    0.967   1
# 20160405NCOB0  2016    3.0     1   9.400  ...    1.647  -0.992    0.920   1
# 20160406NCOB0  2016    1.0     1  10.757  ...    1.462  -0.034    0.773   1
# 20160407NCOB0  2016    1.0     1   7.610  ...    1.171   0.344    0.645   0
#
# [5 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 639 entries, 20160401HTNC0 to 20200719KTNC0
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   시즌       639 non-null    int64
#  1   경기간간격    639 non-null    float64
#  2   홈어웨이     639 non-null    int64
#  3   wRC      639 non-null    float64
#  4   RA/9     639 non-null    float64
#  5   RC27     639 non-null    float64
#  6   vs_wRC   639 non-null    float64
#  7   vs_RC    639 non-null    float64
#  8   vs_RC27  639 non-null    float64
#  9   RC       639 non-null    float64
#  10  whip     639 non-null    float64
#  11  F-E      639 non-null    float64
#  12  OOPS     639 non-null    float64
#  13  vs_RA/9  639 non-null    float64
#  14  vs_whip  639 non-null    float64
#  15  vs_F-E   639 non-null    float64
#  16  vs_OOPS  639 non-null    float64
#  17  결과       639 non-null    int64
# dtypes: float64(15), int64(3)
# memory usage: 94.9+ KB

# %%
def normalization(df, columns, mode='z'):
  if mode == 'm' :
    for colname in columns:
      df[colname] = (df[colname] - df[colname].min())/(df[colname].max()-df[colname].min())
    return df
  if mode == 'z' :
    for colname in columns:
      df[colname] = (df[colname] - df[colname].mean())/df[colname].std()
    return df

# %%
# df = normalization(df,['경기간간격', 'wRC', 'vs_wRC', 'RA/9', 'whip', 'vs_RA/9', 'vs_whip', '득점', '실점'],mode ="m")
df = normalization(df,['경기간간격', 'wRC','RA/9','RC27','vs_wRC','vs_RC','vs_RC27','RC','whip','F-E','OOPS','vs_RA/9','vs_whip','vs_F-E','vs_OOPS'],mode ="z")

# %%
train_data= np.asarray(df[(df['시즌']!= 2019) & (df['시즌']!= 2020)].drop('시즌', axis=1)).astype(np.float32)
val_data= np.asarray(df[df['시즌']==2019].drop('시즌', axis=1)).astype(np.float32)
test_data= np.asarray(df[df['시즌']==2020].drop('시즌', axis=1)).astype(np.float32)

# %%
print("shape of train data: {}".format(train_data.shape))
print("shape of val data: {}".format(val_data.shape))
print("shape of test data: {}".format(test_data.shape))
# Out:
# shape of train data: (432, 17)
# shape of val data: (144, 17)
# shape of test data: (63, 17)

# %%
def make_dataset(data, seq_length=6, target_delay=-1, strides=1):
    sequence = []
    target = []
    for index in range(len(data) - seq_length - target_delay):
        if index % strides == 0:
          sequence.append(data[index:index+seq_length])
          target.append(data[index+seq_length+target_delay][-1])
    return np.array(sequence), np.array(target)

# %%
train_sequences, train_labels = make_dataset(train_data)
val_sequences, val_labels = make_dataset(val_data)
test_sequences, test_labels = make_dataset(test_data)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_sequences, train_labels))
train_dataset = train_dataset.batch(batch_size)
train_dataset = train_dataset.repeat()

# %%
val_dataset = tf.data.Dataset.from_tensor_slices((val_sequences, val_labels))
val_dataset = val_dataset.batch(batch_size)
val_dataset = val_dataset.repeat()

# %%
test_dataset = tf.data.Dataset.from_tensor_slices((test_sequences, test_labels))
test_dataset = test_dataset.batch(batch_size)

# %%
model = tf.keras.Sequential()

# %%
num_layers = len(hidden_sizes)
for i in range(num_layers - 1):
    model.add(tf.keras.layers.LSTM(32,return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.02)))
    model.add(tf.keras.layers.LSTM(16,return_sequences=False,kernel_regularizer=tf.keras.regularizers.l2(0.02)))
    model.add(tf.keras.layers.Dense(1, activation = 'sigmoid'))

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.01) ,loss='binary_crossentropy',metrics=['binary_accuracy'])

# %%
loss, acc = model.evaluate(test_sequences, test_labels)
print("학습 전 모델의 loss: {:.5f}".format(loss))
print("학습 전 모델의 정확도: {:5.2f}%".format(100*acc))
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9955 - binary_accuracy: 0.5000
# 학습 전 모델의 loss: 1.99546
# 학습 전 모델의 정확도: 50.00%

# %%
checkpoint_path = './checkpoint_nodelay6/cp.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)
checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                             save_best_only=True,
                             save_weights_only=True,
                             verbose=1
                            )

# %%
model.fit(train_dataset, steps_per_epoch = train_data.shape[1]/batch_size, 
          validation_data = val_dataset, 
          validation_steps= val_data.shape[1]/batch_size,
          epochs= max_epochs,
          callbacks= [checkpoint])
# Out:
# Epoch 1/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7575 - binary_accuracy: 0.5556
# Epoch 00001: val_loss improved from 1.79001 to 1.78829, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 52ms/step - loss: 1.7613 - binary_accuracy: 0.5556 - val_loss: 1.7883 - val_binary_accuracy: 0.3333
# Epoch 2/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.6976 - binary_accuracy: 0.7778
# Epoch 00002: val_loss improved from 1.78829 to 1.78616, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 50ms/step - loss: 1.7417 - binary_accuracy: 0.6111 - val_loss: 1.7862 - val_binary_accuracy: 0.3333
# Epoch 3/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7083 - binary_accuracy: 0.7778
# Epoch 00003: val_loss improved from 1.78616 to 1.78396, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 85ms/step - loss: 1.6830 - binary_accuracy: 0.8889 - val_loss: 1.7840 - val_binary_accuracy: 0.3333
# Epoch 4/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7823 - binary_accuracy: 0.3333
# Epoch 00004: val_loss improved from 1.78396 to 1.78212, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 53ms/step - loss: 1.7698 - binary_accuracy: 0.4444 - val_loss: 1.7821 - val_binary_accuracy: 0.3333
# Epoch 5/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7413 - binary_accuracy: 0.6667
# Epoch 00005: val_loss improved from 1.78212 to 1.78031, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 118ms/step - loss: 1.7554 - binary_accuracy: 0.6111 - val_loss: 1.7803 - val_binary_accuracy: 0.3333
# Epoch 6/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7736 - binary_accuracy: 0.3333
# Epoch 00006: val_loss improved from 1.78031 to 1.77860, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 54ms/step - loss: 1.7660 - binary_accuracy: 0.4444 - val_loss: 1.7786 - val_binary_accuracy: 0.3333
# Epoch 7/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7712 - binary_accuracy: 0.3333
# Epoch 00007: val_loss improved from 1.77860 to 1.77686, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 78ms/step - loss: 1.7661 - binary_accuracy: 0.4444 - val_loss: 1.7769 - val_binary_accuracy: 0.3333
# Epoch 8/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7585 - binary_accuracy: 0.6667
# Epoch 00008: val_loss improved from 1.77686 to 1.77509, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 98ms/step - loss: 1.7674 - binary_accuracy: 0.5556 - val_loss: 1.7751 - val_binary_accuracy: 0.3333
# Epoch 9/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7605 - binary_accuracy: 0.5556
# Epoch 00009: val_loss improved from 1.77509 to 1.77213, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 90ms/step - loss: 1.7612 - binary_accuracy: 0.5000 - val_loss: 1.7721 - val_binary_accuracy: 0.3889
# Epoch 10/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7617 - binary_accuracy: 0.5556
# Epoch 00010: val_loss improved from 1.77213 to 1.77056, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 55ms/step - loss: 1.7708 - binary_accuracy: 0.5000 - val_loss: 1.7706 - val_binary_accuracy: 0.4444
# Epoch 11/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7415 - binary_accuracy: 0.5556
# Epoch 00011: val_loss improved from 1.77056 to 1.76846, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 59ms/step - loss: 1.7186 - binary_accuracy: 0.6667 - val_loss: 1.7685 - val_binary_accuracy: 0.3889
# Epoch 12/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7666 - binary_accuracy: 0.5556
# Epoch 00012: val_loss improved from 1.76846 to 1.76656, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 129ms/step - loss: 1.7429 - binary_accuracy: 0.6111 - val_loss: 1.7666 - val_binary_accuracy: 0.4444
# Epoch 13/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7848 - binary_accuracy: 0.3333
# Epoch 00013: val_loss improved from 1.76656 to 1.76493, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 53ms/step - loss: 1.7547 - binary_accuracy: 0.5000 - val_loss: 1.7649 - val_binary_accuracy: 0.3889
# Epoch 14/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7527 - binary_accuracy: 0.5556
# Epoch 00014: val_loss improved from 1.76493 to 1.76329, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 141ms/step - loss: 1.7757 - binary_accuracy: 0.3889 - val_loss: 1.7633 - val_binary_accuracy: 0.3889
# Epoch 15/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7314 - binary_accuracy: 0.6667
# Epoch 00015: val_loss improved from 1.76329 to 1.76152, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 54ms/step - loss: 1.7351 - binary_accuracy: 0.6111 - val_loss: 1.7615 - val_binary_accuracy: 0.3889
# Epoch 16/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7709 - binary_accuracy: 0.2222
# Epoch 00016: val_loss improved from 1.76152 to 1.75972, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 103ms/step - loss: 1.7422 - binary_accuracy: 0.5000 - val_loss: 1.7597 - val_binary_accuracy: 0.3889
# Epoch 17/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7578 - binary_accuracy: 0.4444
# Epoch 00017: val_loss improved from 1.75972 to 1.75816, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 84ms/step - loss: 1.7745 - binary_accuracy: 0.4444 - val_loss: 1.7582 - val_binary_accuracy: 0.3889
# Epoch 18/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7419 - binary_accuracy: 0.5556
# Epoch 00018: val_loss improved from 1.75816 to 1.75702, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 116ms/step - loss: 1.7419 - binary_accuracy: 0.5556 - val_loss: 1.7570 - val_binary_accuracy: 0.3333
# Epoch 19/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7197 - binary_accuracy: 0.8889
# Epoch 00019: val_loss did not improve from 1.75702
# 2/1 [===============================] - 0s 9ms/step - loss: 1.7171 - binary_accuracy: 0.8333 - val_loss: 1.7573 - val_binary_accuracy: 0.3333
# Epoch 20/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7362 - binary_accuracy: 0.5556
# Epoch 00020: val_loss improved from 1.75702 to 1.75561, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 56ms/step - loss: 1.7355 - binary_accuracy: 0.5556 - val_loss: 1.7556 - val_binary_accuracy: 0.3333
# Epoch 21/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7108 - binary_accuracy: 0.7778
# Epoch 00021: val_loss improved from 1.75561 to 1.75407, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 150ms/step - loss: 1.7366 - binary_accuracy: 0.5556 - val_loss: 1.7541 - val_binary_accuracy: 0.3333
# Epoch 22/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7492 - binary_accuracy: 0.4444
# Epoch 00022: val_loss improved from 1.75407 to 1.75195, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 61ms/step - loss: 1.7503 - binary_accuracy: 0.4444 - val_loss: 1.7519 - val_binary_accuracy: 0.3333
# Epoch 23/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7245 - binary_accuracy: 0.5556
# Epoch 00023: val_loss improved from 1.75195 to 1.75018, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 110ms/step - loss: 1.7390 - binary_accuracy: 0.5000 - val_loss: 1.7502 - val_binary_accuracy: 0.3333
# Epoch 24/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7100 - binary_accuracy: 0.7778
# Epoch 00024: val_loss improved from 1.75018 to 1.74919, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 56ms/step - loss: 1.7069 - binary_accuracy: 0.7692 - val_loss: 1.7492 - val_binary_accuracy: 0.3333
# Epoch 25/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7167 - binary_accuracy: 0.5556
# Epoch 00025: val_loss improved from 1.74919 to 1.74753, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 56ms/step - loss: 1.7205 - binary_accuracy: 0.5556 - val_loss: 1.7475 - val_binary_accuracy: 0.3333
# Epoch 26/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.6584 - binary_accuracy: 0.7778
# Epoch 00026: val_loss improved from 1.74753 to 1.74546, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 140ms/step - loss: 1.7004 - binary_accuracy: 0.6111 - val_loss: 1.7455 - val_binary_accuracy: 0.3333
# Epoch 27/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.6694 - binary_accuracy: 0.7778
# Epoch 00027: val_loss improved from 1.74546 to 1.74329, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 61ms/step - loss: 1.6446 - binary_accuracy: 0.8889 - val_loss: 1.7433 - val_binary_accuracy: 0.3333
# Epoch 28/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7376 - binary_accuracy: 0.3333
# Epoch 00028: val_loss improved from 1.74329 to 1.74153, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 130ms/step - loss: 1.7272 - binary_accuracy: 0.4444 - val_loss: 1.7415 - val_binary_accuracy: 0.3333
# Epoch 29/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7027 - binary_accuracy: 0.6667
# Epoch 00029: val_loss improved from 1.74153 to 1.73977, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 56ms/step - loss: 1.7167 - binary_accuracy: 0.6667 - val_loss: 1.7398 - val_binary_accuracy: 0.3333
# Epoch 30/30
# 1/1 [==============>...............] - ETA: 0s - loss: 1.7286 - binary_accuracy: 0.4444
# Epoch 00030: val_loss improved from 1.73977 to 1.73813, saving model to ./checkpoint_nodelay6/cp.ckpt
# 2/1 [===============================] - 0s 131ms/step - loss: 1.7253 - binary_accuracy: 0.3889 - val_loss: 1.7381 - val_binary_accuracy: 0.3333

# %%
for sequences, targets in train_dataset.take(1):
    outputs = model(sequences)
    print(outputs)
# Out:
# tf.Tensor(
# [[0.43779063]
#  [0.45331496]
#  [0.47211903]
#  [0.46538267]
#  [0.45444286]
#  [0.44723308]
#  [0.43770877]
#  [0.43178725]
#  [0.43311545]], shape=(9, 1), dtype=float32)

# %%
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))

# %%
loss, acc = model.evaluate(test_sequences, test_labels)
print("학습 후 모델의 loss: {:.5f}".format(loss))
print("학습 후 모델의 정확도: {:5.2f}%".format(100*acc))
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 1.7080 - binary_accuracy: 0.6552
# 학습 후 모델의 loss: 1.70801
# 학습 후 모델의 정확도: 65.52%
